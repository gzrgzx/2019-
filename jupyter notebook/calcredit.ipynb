# %%
import pandas as pd

credit=pd.read_csv("13.csv")#要将excel导出为csv,不能直接修改后缀名

credit
# Out:
#     学期                      课程名称 课程性质   学分   成绩   绩点   课程归属           开课学院  \
# 0    2               思想道德修养与法律基础   必修  2.0   88  3.7    特色类        马克思主义学院
# 1    1                  中国近现代史纲要   必修  2.0   82  3.3    特色类        马克思主义学院
# 2    2      毛泽东思想和中国特色社会主义理论体系概论   必修  3.0   85  3.3    特色类        马克思主义学院
# 3    1                 马克思主义基本原理   必修  3.0   86  3.7    特色类        马克思主义学院
# 4    1                   高等数学A-1   必修  4.0   93  4.0    自然类         数理科学学院
# 5    1                      基础英语   必修  4.0   78  2.7    特色类       外国语言文学学院
# 6    2                   高等数学A-2   必修  4.0   89  3.7    自然类         数理科学学院
# 7    1                      军事理论   必修  1.0   91  4.0    特色类  党委学生工作部、学生事务部
# 8    1                    大学体育-6   必修  0.0   78  2.7    特色类           体育学院
# 9    1                    大学体育-3   必修  1.0   85  3.3    特色类           体育学院
# 10   2                    大学体育-2   必修  1.0   83  3.3    特色类           体育学院
# ...

# %% [markdown]
# cal=credit['课程性质']=='必修'

# %%
cal=pd.DataFrame(credit)

# %%
cal
# Out:
#     学期                      课程名称 课程性质   学分   成绩   绩点   课程归属           开课学院  \
# 0    2               思想道德修养与法律基础   必修  2.0   88  3.7    特色类        马克思主义学院
# 1    1                  中国近现代史纲要   必修  2.0   82  3.3    特色类        马克思主义学院
# 2    2      毛泽东思想和中国特色社会主义理论体系概论   必修  3.0   85  3.3    特色类        马克思主义学院
# 3    1                 马克思主义基本原理   必修  3.0   86  3.7    特色类        马克思主义学院
# 4    1                   高等数学A-1   必修  4.0   93  4.0    自然类         数理科学学院
# 5    1                      基础英语   必修  4.0   78  2.7    特色类       外国语言文学学院
# 6    2                   高等数学A-2   必修  4.0   89  3.7    自然类         数理科学学院
# 7    1                      军事理论   必修  1.0   91  4.0    特色类  党委学生工作部、学生事务部
# 8    1                    大学体育-6   必修  0.0   78  2.7    特色类           体育学院
# 9    1                    大学体育-3   必修  1.0   85  3.3    特色类           体育学院
# 10   2                    大学体育-2   必修  1.0   83  3.3    特色类           体育学院
# ...

# %%
cal.index=cal['课程性质'] # 将A列作为DataFrame的行索引
c=cal.loc['必修', :]

# %%
c
# Out:
#       学期                  课程名称 课程性质   学分  成绩   绩点 课程归属           开课学院   课程类别
# 课程性质
# 必修     2           思想道德修养与法律基础   必修  2.0  88  3.7  特色类        马克思主义学院  通识教育课
# 必修     1              中国近现代史纲要   必修  2.0  82  3.3  特色类        马克思主义学院  通识教育课
# 必修     2  毛泽东思想和中国特色社会主义理论体系概论   必修  3.0  85  3.3  特色类        马克思主义学院  通识教育课
# 必修     1             马克思主义基本原理   必修  3.0  86  3.7  特色类        马克思主义学院  通识教育课
# 必修     1               高等数学A-1   必修  4.0  93  4.0  自然类         数理科学学院  通识教育课
# 必修     1                  基础英语   必修  4.0  78  2.7  特色类       外国语言文学学院  通识教育课
# 必修     2               高等数学A-2   必修  4.0  89  3.7  自然类         数理科学学院  通识教育课
# 必修     1                  军事理论   必修  1.0  91  4.0  特色类  党委学生工作部、学生事务部  通识教育课
# 必修     1                大学体育-6   必修  0.0  78  2.7  特色类           体育学院  通识教育课
# 必修     1                大学体育-3   必修  1.0  85  3.3  特色类           体育学院  通识教育课
# 必修     2                大学体育-2   必修  1.0  83  3.3  特色类           体育学院  通识教育课
# ...

# %%
c['学分'].sum()
# Out:
# 98.0
